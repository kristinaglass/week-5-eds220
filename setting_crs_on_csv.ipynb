# %% [markdown]
# ## About our data
#
# Dataset 1:
# From the US Energy Information Administration (EIA).
# Infro about current operble electric powerplants in te US by energy Source
#
# Dataset 2:
# From US Census beaureu depicting state boundaties

# %%
#import necessary librarues
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

#update pandas display option
pd.set_option("display.max.columns", None)

# %% [raw]
# We want to make geopandas geodatarame from out csv data.

# %% [raw]
# We want to make geopandas geodatarame from out csv data.

# %%
#import csv data using pandas
power_plants = pd.read_csv('data/power_plants_epsg4269.csv')
power_plants.head(3)
# Out:
#    Unnamed: 0 objectid plant_code    plant_name utility_id  \
# 0         0.0    11570          1    Sand Point      63560
# 1         1.0    11571          2  Bankhead Dam        195
# 2         2.0    11572          3         Barry        195
#
#                      utility_name       sector_name       street_address  \
# 0  TDX Sand Point Generating, LLC  Electric Utility  100 Power Plant Way
# 1                Alabama Power Co  Electric Utility   19001 Lock 17 Road
# 2                Alabama Power Co  Electric Utility     North Highway 43
#
#          city          county    state      zip     primsource  \
# 0  Sand Point  Aleutians East   Alaska  99661.0      petroleum
# 1   Northport      Tuscaloosa  Alabama  35476.0  hydroelectric
# 2       Bucks          Mobile  Alabama  36512.0    natural gas
#
#                                  source_desc  \
# 0          Petroleum = 1.3 MW, Wind = 0.4 MW
# 1                      Hydroelectric = 53 MW
# ...

# %% [markdown]
# From the "documentation" we know that the crs from this file is EPSG 4269 in lat long coordinates.
# We can use this information to create a new `gpd.GeoDataFrame` from the `pd.DataFrame`.
# To do this, we use the `gpd.points_from_xy` function:

# %%
power_plants = gpd.GeoDataFrame( power_plants, #data for geodataframe
                               # specify or create a geometry columns
                               geometry = gpd.points_from_xy(power_plants.longitude,
                                                            power_plants.latitude),
                               #specify CRS
                               crs='EPSG:4269'
                               )

power_plants.head()
# Out:
#    Unnamed: 0 objectid plant_code          plant_name utility_id  \
# 0         0.0    11570          1          Sand Point      63560
# 1         1.0    11571          2        Bankhead Dam        195
# 2         2.0    11572          3               Barry        195
# 3         3.0    11573          4  Walter Bouldin Dam        195
# 4         4.0    11574          9              Copper       5701
#
#                      utility_name       sector_name        street_address  \
# 0  TDX Sand Point Generating, LLC  Electric Utility   100 Power Plant Way
# 1                Alabama Power Co  Electric Utility    19001 Lock 17 Road
# 2                Alabama Power Co  Electric Utility      North Highway 43
# 3                Alabama Power Co  Electric Utility  750 Bouldin Dam Road
# 4             El Paso Electric Co  Electric Utility     651 Hawkins Blvd.
#
#          city          county    state      zip     primsource  \
# ...

# %% [markdown]
# Lets check information about our CRS

# %%
#print CRS info
print('is geographic? ', power_plants.crs.is_geographic)
print('is projected? ', power_plants.crs.is_projected)
print('datum: ', power_plants.crs.datum)
print('ellipsoid: ', power_plants.crs.ellipsoid)

power_plants.crs
# Out:
# is geographic?  True
# is projected?  False
# datum:  North American Datum 1983
# ellipsoid:  GRS 1980
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - NAD83
# - bounds: (167.65, 14.92, -47.74, 86.46)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
# import tiger lines as states
states = gpd.read_file('data/tl_2022_us_state/tl_2022_us_state.shp')

# %%
#simplify column names

states.columns = map(str.lower, states.columns)
states.head()
# Out:
#   region division statefp   statens geoid stusps           name lsad  mtfcc  \
# 0      3        5      54  01779805    54     WV  West Virginia   00  G4000
# 1      3        5      12  00294478    12     FL        Florida   00  G4000
# 2      2        3      17  01779784    17     IL       Illinois   00  G4000
# 3      2        4      27  00662849    27     MN      Minnesota   00  G4000
# 4      3        5      24  01714934    24     MD       Maryland   00  G4000
#
#   funcstat         aland       awater     intptlat      intptlon  \
# 0        A   62266456923    489045863  +38.6472854  -080.6183274
# 1        A  138962819934  45971472526  +28.3989775  -082.5143005
# 2        A  143778515726   6216539665  +40.1028754  -089.1526108
# 3        A  206244837557  18937184315  +46.3159573  -094.1996043
# 4        A   25151771744   6979295311  +38.9466584  -076.6744939
#
#                                             geometry
# 0  POLYGON ((-77.75438 39.33346, -77.75422 39.333...
# ...

# %%
states.dtypes
# Out:
# region        object
# division      object
# statefp       object
# statens       object
# geoid         object
# stusps        object
# name          object
# lsad          object
# mtfcc         object
# funcstat      object
# aland          int64
# awater         int64
# intptlat      object
# intptlon      object
# geometry    geometry
# dtype: object

# %%
#update region, division, and statefp to be as integer
states['region'] = pd.to_numeric(states['region'])
states['division'] = pd.to_numeric(states['division'])
states['statefp'] = pd.to_numeric(states['statefp'])

# %%
states.dtypes
# Out:
# region         int64
# division       int64
# statefp        int64
# statens       object
# geoid         object
# stusps        object
# name          object
# lsad          object
# mtfcc         object
# funcstat      object
# aland          int64
# awater         int64
# intptlat      object
# intptlon      object
# geometry    geometry
# dtype: object

# %%
#check crs
print('is projected? ', states.crs.is_projected)
print('datum: ', states.crs.datum)
print('ellipsoid: ', states.crs.ellipsoid)

states.crs
# Out:
# is projected?  False
# datum:  North American Datum 1983
# ellipsoid:  GRS 1980
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - NAD83
# - bounds: (167.65, 14.92, -47.74, 86.46)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
print('is projected? ', power_plants.crs.is_projected)
print('datum: ', power_plants.crs.datum)
print('ellipsoid: ', power_plants.crs.ellipsoid)

power_plants.crs
# Out:
# is projected?  False
# datum:  North American Datum 1983
# ellipsoid:  GRS 1980
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - NAD83
# - bounds: (167.65, 14.92, -47.74, 86.46)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
states.plot()
# Out:
# <AxesSubplot:>

# %%
states.region.unique()
# Out:
# array([3, 2, 1, 4, 9])

# %%
states
# Out:
#     region  division  statefp   statens geoid stusps  \
# 0        3         5       54  01779805    54     WV
# 1        3         5       12  00294478    12     FL
# 2        2         3       17  01779784    17     IL
# 3        2         4       27  00662849    27     MN
# 4        3         5       24  01714934    24     MD
# 5        1         1       44  01219835    44     RI
# 6        4         8       16  01779783    16     ID
# 7        1         1       33  01779794    33     NH
# 8        3         5       37  01027616    37     NC
# 9        1         1       50  01779802    50     VT
# 10       1         1        9  01779780    09     CT
# 11       3         5       10  01779781    10     DE
# 12       4         8       35  00897535    35     NM
# 13       4         9        6  01779778    06     CA
# 14       1         2       34  01779795    34     NJ
# 15       2         3       55  01779806    55     WI
# 16       4         9       41  01155107    41     OR
# ...

# %%
power_plants.head()
# Out:
#    Unnamed: 0 objectid plant_code          plant_name utility_id  \
# 0         0.0    11570          1          Sand Point      63560
# 1         1.0    11571          2        Bankhead Dam        195
# 2         2.0    11572          3               Barry        195
# 3         3.0    11573          4  Walter Bouldin Dam        195
# 4         4.0    11574          9              Copper       5701
#
#                      utility_name       sector_name        street_address  \
# 0  TDX Sand Point Generating, LLC  Electric Utility   100 Power Plant Way
# 1                Alabama Power Co  Electric Utility    19001 Lock 17 Road
# 2                Alabama Power Co  Electric Utility      North Highway 43
# 3                Alabama Power Co  Electric Utility  750 Bouldin Dam Road
# 4             El Paso Electric Co  Electric Utility     651 Hawkins Blvd.
#
#          city          county    state      zip     primsource  \
# ...

# %%
states = states.loc[states['statefp'] <= 56]

# %%
states = states.loc[states['region'] <= 4]

# %%
states.plot()
# Out:
# <AxesSubplot:>
